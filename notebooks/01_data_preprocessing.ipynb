# %%
# Import required libraries
import pandas as pd
import numpy as np
import os
from pathlib import Path
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.model_selection import train_test_split, KFold
from scipy import stats

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# Set style for plots
plt.style.use('default') 
sns.set_theme()

def load_cbcl_depression():
    """Load depression scores and clean"""
    # Load CBCL data
    cbcl_file = "../data/core/mental-health/mh_p_cbcl.csv"
    cbcl_df = pd.read_csv(cbcl_file, low_memory=False)
    
    # Get 3-year follow-up 
    followup_mask = cbcl_df['eventname'].str.contains('3_year', case=False, na=False)
    followup_df = cbcl_df[followup_mask].copy()
    
    # Get depression score 
    dep_col = [col for col in followup_df.columns if 'depress' in col.lower() and 'dsm5' in col.lower()][0]
    
    # Remove subjects with missing /r invalid (555,999,777) scores
    invalid_scores = [555, 999, 777, np.nan]
    valid_mask = ~followup_df[dep_col].isin(invalid_scores)
    clean_df = followup_df[valid_mask].copy()
    
    # only get necessary columns
    result_df = clean_df[['src_subject_id', dep_col]].copy()
    result_df = result_df.rename(columns={dep_col: 'depression_score'})
    
    print(f"Original subjects: {len(followup_df)}")
    print(f"Subjects after cleaning: {len(result_df)}")
    print(f"\nDepression score statistics:")
    print(result_df['depression_score'].describe())
    
    return result_df

def load_baseline_data(subject_ids):
    """Load baseline data for only  subjects with CBCL dsm5 depress scores. Get all data from all core subfolders, excluding CBCL scores"""
    core_dir = Path("../data/core")
    all_data = []
    
    # Calculate min required subjects (80% of full cohort -- we get rid of files missing over 20%)
    min_subjects = len(subject_ids) * 0.8
    print(f"Minimum required subjects per file: {min_subjects:.0f}")
    
    # Process each subdirectory 
    for subdir in core_dir.iterdir():
        if not subdir.is_dir():
            continue
            
        print(f"\nProcessing {subdir.name}...")
        subdir_data = []
        
        # Skip CBCL directory
        if 'cbcl' in subdir.name.lower():
            print(f"Skipping {subdir.name} (CBCL data excluded)")
            continue
        
        for file in subdir.glob('*.csv'):
            try:
                # don't get CBCL --- too colinear with future CBCL depression 
                if 'cbcl' in file.name.lower():
                    print(f"  - Skipping {file.name} (CBCL data excluded)")
                    continue
                
                # Load data
                df = pd.read_csv(file, low_memory=False)
                
                # Check if file has subject ID column -- fixes issue 
                if 'src_subject_id' not in df.columns:
                    continue
                    
                # Get baseline data
                if 'eventname' in df.columns:
                    baseline_mask = df['eventname'].str.contains('baseline', case=False, na=False)
                    df = df[baseline_mask].copy()
                
                # Filter for our subjects
                df = df[df['src_subject_id'].isin(subject_ids)].copy()
                
                # Only keep files with >80% subjects
                if len(df) >= min_subjects:
                    print(f"  - {file.name}: {len(df)} subjects (keeping)")
                    # Add source information to column names
                    df.columns = [f"{col}_{subdir.name}_{file.stem}" if col not in ['src_subject_id', 'eventname'] else col 
                                for col in df.columns]
                    subdir_data.append(df)
                else:
                    print(f"  - {file.name}: {len(df)} subjects (skipping - too few subjects)")
                
            except Exception as e:
                print(f"  - Error loading {file.name}: {str(e)}")
        
        # Merge data within each subdirectory -- otherwise stalls out 
        if subdir_data:
            print(f"Merging {len(subdir_data)} files from {subdir.name}...")
            subdir_merged = subdir_data[0]
            for i, df in enumerate(subdir_data[1:], 1):
                suffixes = (f'_{i}', f'_{i+1}')
                subdir_merged = pd.merge(subdir_merged, df, on='src_subject_id', how='outer', suffixes=suffixes)
            all_data.append(subdir_merged)
            print(f"Completed {subdir.name} merge. Shape: {subdir_merged.shape}")
    
    # Merge subdirectory dataframes
    if all_data:
        print("\nMerging all subdirectories...")
        final_df = all_data[0]
        for i, df in enumerate(all_data[1:], 1):
            print(f"Merging subdirectory {i+1} of {len(all_data)}...")
            suffixes = (f'_dir{i}', f'_dir{i+1}')
            final_df = pd.merge(final_df, df, on='src_subject_id', how='outer', suffixes=suffixes)
            print(f"Current shape: {final_df.shape}")
        return final_df
    return None

def create_depression_categories(df):
    """Create depression categories using statistical methods to identify high scores"""
    # Calculate statistics
    mean = df['depression_score'].mean()
    std = df['depression_score'].std()
    q1 = df['depression_score'].quantile(0.25)
    q3 = df['depression_score'].quantile(0.75)
    iqr = q3 - q1
    
    # Calculate thresholds using both methods
    z_score_threshold = mean + 2*std  # Scores > 2 SD above mean
    iqr_threshold = q3 + 1.5*iqr      # Scores > Q3 + 1.5*IQR
    
    # Use IQR method (more robust to non-normal distribution)
    high_threshold = iqr_threshold
    
    # Create categories
    df['depression_category'] = pd.cut(
        df['depression_score'],
        bins=[-np.inf, q1, q3, np.inf],
        labels=['low', 'medium', 'high']
    )
    
    # Create binary depression (1 for high, 0 for others)
    df['depression_binary'] = (df['depression_category'] == 'high').astype(int)
    
    # Print distribution information
    print("\nDepression Score Statistics:")
    print(f"Mean: {mean:.2f}")
    print(f"Std: {std:.2f}")
    print(f"Q1 (25th percentile): {q1:.2f}")
    print(f"Q3 (75th percentile): {q3:.2f}")
    print(f"IQR: {iqr:.2f}")
    
    print("\nThresholds:")
    print(f"Z-score method (2 SD above mean): {z_score_threshold:.2f}")
    print(f"IQR method (Q3 + 1.5*IQR): {iqr_threshold:.2f}")
    
    print("\nDepression Categories Distribution:")
    print(df['depression_category'].value_counts(normalize=True))
    
    return df

class DataPreprocessor:
    """
    A class to handle all data preprocessing steps for the ABCD dataset
    """
    def __init__(self, missing_threshold=0.2, 
                 cont_var_threshold=0.01, 
                 cat_var_threshold=0.01,
                 correlation_threshold=0.95,
                 unique_threshold=20,
                 sample_ratio_threshold=0.1,
                 output_dir='../data/processed'):
        """
        Initialize preprocessing parameters
        """
        self.missing_threshold = missing_threshold
        self.cont_var_threshold = cont_var_threshold
        self.cat_var_threshold = cat_var_threshold
        self.correlation_threshold = correlation_threshold
        self.unique_threshold = unique_threshold
        self.sample_ratio_threshold = sample_ratio_threshold
        self.output_dir = output_dir
        self.encoders = {}
        self.scaler = None
        
        # Create output directory if it doesn't exist
        Path(output_dir).mkdir(parents=True, exist_ok=True)
        
    def identify_variable_types(self, df):
        """
        Identify continuous, categorical, and binary variables
        """
        continuous_vars = []
        categorical_vars = []
        binary_vars = []
        
        for col in df.columns:
            if col in ['src_subject_id', 'depression_score']:
                continue
                
            n_unique = df[col].nunique()
            n_samples = len(df)
            unique_ratio = n_unique / n_samples
            is_numeric = pd.api.types.is_numeric_dtype(df[col])
            
            # Binary variables
            if n_unique == 2:
                binary_vars.append(col)
                continue
                
            # Non-numeric variables are categorical
            if not is_numeric:
                categorical_vars.append(col)
                continue
                
            # Numeric variables need further investigation
            if is_numeric:
                is_integer = df[col].dtype in ['int32', 'int64']
                if (is_integer and n_unique <= self.unique_threshold) or \
                   (n_unique <= self.unique_threshold and unique_ratio <= self.sample_ratio_threshold):
                    value_counts = df[col].value_counts(normalize=True)
                    if value_counts.max() < 0.5:  # No single value dominates
                        categorical_vars.append(col)
                    else:
                        continuous_vars.append(col)
                else:
                    continuous_vars.append(col)
        
        return continuous_vars, categorical_vars, binary_vars
    
    def handle_special_values(self, df):
        """
        Convert special values (555, 777, 999) to NaN before missing value analysis
        """
        print("\nHandling special values...")
        special_values = [555, 777, 999]
        special_value_counts = {val: 0 for val in special_values}
        
        # Count special values in each column
        for col in df.columns:
            if col in ['src_subject_id', 'depression_score']:
                continue
            for val in special_values:
                count = (df[col] == val).sum()
                if count > 0:
                    special_value_counts[val] += count
                    print(f"Found {count} instances of {val} in {col}")
                    # Convert to NaN
                    df[col] = df[col].replace(val, np.nan)
        
        # Print summary
        print("\nSpecial value summary:")
        for val, count in special_value_counts.items():
            if count > 0:
                print(f"Total {val} values converted to NaN: {count}")
        
        return df

    def handle_missing_values(self, df, depression_df):
        """
        Handle missing values in the dataset:
        1. Convert special values to NaN
        2. Remove variables with high missingness
        3. Impute missing values:
           - Mean imputation for numerical variables
           - Mode imputation for categorical variables
        """
        print("\nHandling missing values...")
        
        # Step 1: Convert special values to NaN
        df = self.handle_special_values(df)
        
        # Step 2: Calculate missingness after special value conversion
        merged_df = pd.merge(df, depression_df[['src_subject_id']], 
                            on='src_subject_id', how='inner')
        missingness = merged_df.isnull().sum() / len(merged_df)
        
        # Print missing value statistics before removal
        print("\nMissing value statistics before removing high missingness variables:")
        high_missing_vars = missingness[missingness > self.missing_threshold]
        if not high_missing_vars.empty:
            print("\nVariables with high missingness:")
            for var, missing_pct in high_missing_vars.items():
                print(f"  - {var}: {missing_pct:.1%} missing")
        
        # Remove columns with high missingness
        keep_cols = missingness[missingness <= self.missing_threshold].index
        clean_df = df[keep_cols].copy()
        print(f"\nRemoved {len(df.columns) - len(keep_cols)} variables due to missingness")
        
        # Identify numeric and categorical columns for imputation
        numeric_cols = clean_df.select_dtypes(include=['int64', 'float64']).columns
        numeric_cols = [col for col in numeric_cols if col not in ['src_subject_id', 'depression_score']]
        
        categorical_cols = clean_df.select_dtypes(exclude=['int64', 'float64']).columns
        categorical_cols = [col for col in categorical_cols if col not in ['src_subject_id', 'depression_score']]
        
        # Calculate and print missing value statistics before imputation
        print("\nMissing values before imputation:")
        
        # Numeric variables
        numeric_missing = clean_df[numeric_cols].isnull().sum()
        total_numeric_missing = numeric_missing.sum()
        if total_numeric_missing > 0:
            print("\nNumeric variables:")
            print(f"Total missing values: {total_numeric_missing}")
            for col in numeric_cols:
                n_missing = numeric_missing[col]
                if n_missing > 0:
                    print(f"  - {col}: {n_missing} missing values ({n_missing/len(clean_df):.1%})")
        
        # Categorical variables
        categorical_missing = clean_df[categorical_cols].isnull().sum()
        total_categorical_missing = categorical_missing.sum()
        if total_categorical_missing > 0:
            print("\nCategorical variables:")
            print(f"Total missing values: {total_categorical_missing}")
            for col in categorical_cols:
                n_missing = categorical_missing[col]
                if n_missing > 0:
                    print(f"  - {col}: {n_missing} missing values ({n_missing/len(clean_df):.1%})")
        
        # Mean imputation for continuuos variables
        print("\nPerforming mean imputation for numeric variables...")
        for col in numeric_cols:
            if clean_df[col].isnull().any():
                mean_value = clean_df[col].mean()
                n_missing = clean_df[col].isnull().sum()
                clean_df[col] = clean_df[col].fillna(mean_value)
                print(f"Imputed {n_missing} missing values in {col} with mean: {mean_value:.2f}")
        
        #  Mode imputation for categorical variables
        print("\nPerforming mode imputation for categorical variables...")
        for col in categorical_cols:
            if clean_df[col].isnull().any():
                mode_value = clean_df[col].mode()[0]  # Get the most common value
                n_missing = clean_df[col].isnull().sum()
                clean_df[col] = clean_df[col].fillna(mode_value)
                print(f"Imputed {n_missing} missing values in {col} with mode: {mode_value}")
        
        # Verify no missing values 
        remaining_numeric_missing = clean_df[numeric_cols].isnull().sum().sum()
        remaining_categorical_missing = clean_df[categorical_cols].isnull().sum().sum()
        
        if remaining_numeric_missing > 0 or remaining_categorical_missing > 0:
            print(f"\nWarning: {remaining_numeric_missing + remaining_categorical_missing} missing values remain after imputation")
            if remaining_numeric_missing > 0:
                print(f"  - {remaining_numeric_missing} in numeric columns")
            if remaining_categorical_missing > 0:
                print(f"  - {remaining_categorical_missing} in categorical columns")
        else:
            print("\nAll missing values have been imputed")
        
        return clean_df
    
    def remove_low_variance_variables(self, df, continuous_vars):
        """
        Remove variables with low variance
        """
        print("\nRemoving low variance variables...")
        n_cols_before = len(df.columns)
        removed_vars = []
        
        for var in continuous_vars:
            if var in ['src_subject_id', 'depression_score']:
                continue
            if var not in df.columns:
                continue
            std = df[var].std()
            mean = df[var].mean()
            if mean != 0:
                cv = std / abs(mean)
                if cv <= self.cont_var_threshold:
                    df = df.drop(columns=[var])
                    removed_vars.append(f"{var} (continuous, cv={cv:.3f})")
        
        print(f"Removed {n_cols_before - len(df.columns)} low variance variables")
        if removed_vars:
            print("\nRemoved variables:")
            for var in removed_vars:
                print(f"  - {var}")
        
        return df
        
    def track_variables(self, df, stage_name):
        """
        Track which variables are present at each stage
        """
        print(f"\nVariables present after {stage_name}:")
        print(f"Total columns: {len(df.columns)}")
        numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns
        print(f"Numeric columns: {len(numeric_cols)}")
        categorical_cols = df.select_dtypes(exclude=['int64', 'float64']).columns
        print(f"Categorical columns: {len(categorical_cols)}")
        return df

    def encode_categorical_variables(self, df, categorical_vars, binary_vars):
        """
        Encode categorical and binary variables
        """
        print("\nEncoding categorical variables...")
        
        # binary variables 
        for var in binary_vars:
            if var in df.columns:
                print(f"Using binary encoding for {var}")
                df[var] = (df[var] == df[var].value_counts().index[0]).astype(int)
                self.encoders[var] = 'binary'
        
        #  categorical variables
        for var in categorical_vars:
            if var in df.columns:
                if df[var].dtype in ['int64', 'float64'] or len(df[var].unique()) > 10:
                    print(f"Using ordinal encoding for {var}")
                    self.encoders[var] = OrdinalEncoder(handle_unknown='use_encoded_value', 
                                                      unknown_value=-1)
                    values = df[var].values.reshape(-1, 1)
                    df[var] = self.encoders[var].fit_transform(values)
                else:
                    print(f"Using one-hot encoding for {var}")
                    self.encoders[var] = OneHotEncoder(handle_unknown='ignore', sparse=False)
                    values = df[var].values.reshape(-1, 1)
                    encoded_values = self.encoders[var].fit_transform(values)
                    feature_names = [f"{var}_{i}" for i in range(encoded_values.shape[1])]
                    encoded_df = pd.DataFrame(encoded_values, columns=feature_names, index=df.index)
                    df = pd.concat([df.drop(columns=[var]), encoded_df], axis=1)
        
        return df
    
    def scale_numerical_variables(self, df, continuous_vars):
            """
            Scale numerical variables including depression score
            """
            print("\nScaling numerical variables...")
            self.scaler = StandardScaler()
            
            # Filter continuous_vars to only include those that still exist in the dataframe
            existing_continuous_vars = [var for var in continuous_vars if var in df.columns]
            
            # Add depression score to variables to scale
            vars_to_scale = existing_continuous_vars + ['depression_score']
            
            if not vars_to_scale:
                print("No continuous variables found to scale")
                return df
                
            print(f"Scaling {len(vars_to_scale)} continuous variables (including depression score)")
            df[vars_to_scale] = self.scaler.fit_transform(df[vars_to_scale])
            
            # Print statistics before and after scaling
            print("\nDepression score statistics before scaling:")
            print(df['depression_score'].describe())
            
            return df

    def transform_skewed_features(self, df, continuous_vars):
        """
        Apply log transformation to skewed features
        """
        print("\nApplying log transformation to skewed features...")
        
        # Filter continuous_vars to only include those that still exist in the dataframe
        existing_continuous_vars = [var for var in continuous_vars if var in df.columns]
        
        if not existing_continuous_vars:
            print("No continuous variables found to transform")
            return df
            
        for col in existing_continuous_vars:
            skewness = stats.skew(df[col].dropna())
            if abs(skewness) > 1:
                print(f"Log transforming {col} (skewness: {skewness:.2f})")
                df[col] = np.log1p(df[col] - df[col].min() + 1)
        
        return df

    def remove_correlated_features(self, df):
        """
        Remove highly correlated features
        """
        print("\nRemoving correlated features...")
        numeric_df = df.select_dtypes(include=['int64', 'float64'])
        corr_matrix = numeric_df.corr().abs()
        upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
        to_drop = [column for column in upper.columns if any(upper[column] > self.correlation_threshold)]
        df = df.drop(columns=to_drop)
        print(f"Removed {len(to_drop)} highly correlated variables")
        return df

        
        return clean_df
    
    def remove_low_variance_variables(self, df, continuous_vars):
        """
        Remove variables with low variance
        """
        print("\nRemoving low variance variables...")
        n_cols_before = len(df.columns)
        removed_vars = []
        
        # Remove low variance continuous variables
        for var in continuous_vars:
            if var in ['src_subject_id', 'depression_score']:
                continue
            if var not in df.columns:
                continue
            std = df[var].std()
            mean = df[var].mean()
            if mean != 0:
                cv = std / abs(mean)
                if cv <= self.cont_var_threshold:
                    df = df.drop(columns=[var])
                    removed_vars.append(f"{var} (continuous, cv={cv:.3f})")
        
        print(f"Removed {n_cols_before - len(df.columns)} low variance variables")
        if removed_vars:
            print("\nRemoved variables:")
            for var in removed_vars:
                print(f"  - {var}")
        
        return df
        
    def track_variables(self, df, stage_name):
        """
        Track which variables are present at each stage
        """
        print(f"\nVariables present after {stage_name}:")
        print(f"Total columns: {len(df.columns)}")
        numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns
        print(f"Numeric columns: {len(numeric_cols)}")
        categorical_cols = df.select_dtypes(exclude=['int64', 'float64']).columns
        print(f"Categorical columns: {len(categorical_cols)}")
        return df

    def encode_categorical_variables(self, df, categorical_vars, binary_vars):
        """
        Encode categorical and binary variables
        """
        print("\nEncoding categorical variables...")
        
        # binary variables 
        for var in binary_vars:
            if var in df.columns:
                print(f"Using binary encoding for {var}")
                df[var] = (df[var] == df[var].value_counts().index[0]).astype(int)
                self.encoders[var] = 'binary'
        
        #  categorical variables
        for var in categorical_vars:
            if var in df.columns:
                if df[var].dtype in ['int64', 'float64'] or len(df[var].unique()) > 10:
                    print(f"Using ordinal encoding for {var}")
                    self.encoders[var] = OrdinalEncoder(handle_unknown='use_encoded_value', 
                                                      unknown_value=-1)
                    values = df[var].values.reshape(-1, 1)
                    df[var] = self.encoders[var].fit_transform(values)
                else:
                    print(f"Using one-hot encoding for {var}")
                    self.encoders[var] = OneHotEncoder(handle_unknown='ignore', sparse_output=False)
                    values = df[var].values.reshape(-1, 1)
                    encoded_values = self.encoders[var].fit_transform(values)
                    feature_names = [f"{var}_{i}" for i in range(encoded_values.shape[1])]
                    encoded_df = pd.DataFrame(encoded_values, columns=feature_names, index=df.index)
                    df = pd.concat([df.drop(columns=[var]), encoded_df], axis=1)
        
        return df
    
    def scale_numerical_variables(self, df, continuous_vars):
        """
        Scale numerical variables
        """
        print("\nScaling numerical variables...")
        self.scaler = StandardScaler()
        
        # Filter continuous_vars to only include those that still exist in the dataframe
        existing_continuous_vars = [var for var in continuous_vars if var in df.columns]
        
        if not existing_continuous_vars:
            print("No continuous variables found to scale")
            return df
            
        print(f"Scaling {len(existing_continuous_vars)} continuous variables")
        df[existing_continuous_vars] = self.scaler.fit_transform(df[existing_continuous_vars])
        
        return df

    def transform_skewed_features(self, df, continuous_vars):
        """
        Apply log transformation to skewed features
        """
        print("\nApplying log transformation to skewed features...")
        
        # Filter continuous_vars to only include those that still exist in the dataframe
        existing_continuous_vars = [var for var in continuous_vars if var in df.columns]
        
        if not existing_continuous_vars:
            print("No continuous variables found to transform")
            return df
            
        for col in existing_continuous_vars:
            skewness = stats.skew(df[col].dropna())
            if abs(skewness) > 1:
                print(f"Log transforming {col} (skewness: {skewness:.2f})")
                df[col] = np.log1p(df[col] - df[col].min() + 1)
        
        return df

    def remove_correlated_features(self, df):
        """
        Remove highly correlated features
        """
        print("\nRemoving correlated features...")
        numeric_df = df.select_dtypes(include=['int64', 'float64'])
        corr_matrix = numeric_df.corr().abs()
        upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
        to_drop = [column for column in upper.columns if any(upper[column] > self.correlation_threshold)]
        df = df.drop(columns=to_drop)
        print(f"Removed {len(to_drop)} highly correlated variables")
        return df

    def remove_temporal_variables(self, df):
        """
        Remove variables containing temporal information (eventname, date, timestamp)
        """
        print("\nRemoving temporal variables...")
        temporal_keywords = ['eventname', 'date', 'timestamp']
        
        # Find columns containing temporal keywords
        temporal_cols = [col for col in df.columns 
                        if any(keyword in col.lower() for keyword in temporal_keywords)]
        
        # Remove temporal columns
        if temporal_cols:
            print(f"Removing {len(temporal_cols)} temporal variables:")
            for col in temporal_cols:
                print(f"  - {col}")
            df = df.drop(columns=temporal_cols)
        else:
            print("No temporal variables found")
            
        return df

    def preprocess(self, baseline_df, depression_df):
        """
        Run the complete preprocessing pipeline without train/test split
        """
        print("Starting data preprocessing pipeline...")
        
        # Step 1: Handle missing values
        df_before = baseline_df.copy()
        df = self.handle_missing_values(baseline_df, depression_df)
        
        # Step 1.5: Remove temporal variables
        df = self.remove_temporal_variables(df)
        
        # Identify columns for visualization
        numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns
        numeric_cols = [col for col in numeric_cols if col not in ['src_subject_id', 'depression_score']]
        
        categorical_cols = df.select_dtypes(exclude=['int64', 'float64']).columns
        categorical_cols = [col for col in categorical_cols if col not in ['src_subject_id', 'depression_score']]
        
        # Step 2: Identify variable types
        continuous_vars, categorical_vars, binary_vars = self.identify_variable_types(df)
        print(f"\nIdentified {len(continuous_vars)} continuous, {len(categorical_vars)} categorical, "
              f"and {len(binary_vars)} binary variables")
        
        # Step 3: Remove low variance variables
        df = self.remove_low_variance_variables(df, continuous_vars)
        df = self.track_variables(df, "low variance removal")
            
        # Step 4: Encode categorical variables
        df = self.encode_categorical_variables(df, categorical_vars, binary_vars)
        
        # Step 5: Scale numerical variables
        df = self.scale_numerical_variables(df, continuous_vars)
        
        # Step 6: Transform skewed features
        df = self.transform_skewed_features(df, continuous_vars)
        
        # Step 7: Remove correlated features
        df = self.remove_correlated_features(df)
        
        # Step 8: Add depression scores
        df = pd.merge(df, depression_df[['src_subject_id', 'depression_score']], 
                     on='src_subject_id', how='inner')

        # Step 9: Scale depression score
        print("\nScaling depression score...")
        df['depression_score'] = self.scaler.fit_transform(df[['depression_score']])
        print("\nDepression score statistics after scaling:")
        print(df['depression_score'].describe())
        
        # Print final dataset information
        print("\nFinal preprocessed dataset:")
        print(f"Shape: {df.shape}")
        
        # Print final dataset information
        print("\nFinal preprocessed dataset:")
        print(f"Shape: {df.shape}")
        print("\nFeature types:")
        print(df.dtypes.value_counts())
        
        # Save the preprocessed dataset
        output_path = Path(self.output_dir) / 'preprocessed_data.csv'
        df.to_csv(output_path, index=False)
        print(f"\nPreprocessed data saved to: {output_path}")
        
        # Return the preprocessed data and preprocessing objects
        return {
            'data': df,
            'encoders': self.encoders,
            'scaler': self.scaler,
            'variable_types': {
                'continuous': continuous_vars,
                'categorical': categorical_vars,
                'binary': binary_vars
            }
        }

def main():
    # Load CBCL depression data
    print("Loading CBCL depression data...")
    depression_df = load_cbcl_depression()
    
    # Create depression categories
    print("\nCreating depression categories...")
    depression_df = create_depression_categories(depression_df)
    
    # Load baseline data for our subjects
    print("\nStarting baseline data loading...")
    baseline_df = load_baseline_data(depression_df['src_subject_id'])
    print(f"\nFinal baseline dataset shape: {baseline_df.shape}")
    
    # run preprocessing pipeline
    print("\nStarting preprocessing pipeline...")
    preprocessor = DataPreprocessor()
    preprocessed_data = preprocessor.preprocess(baseline_df, depression_df)
    
    print("\nDone!")

if __name__ == "__main__":
    main()
# Out:
# Loading CBCL depression data...
# Original subjects: 10098
# Subjects after cleaning: 10094
#
# Depression score statistics:
# count    10094.000000
# mean         1.690113
# std          2.520788
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          2.000000
# max         21.000000
# Name: depression_score, dtype: float64
#
# Creating depression categories...
#
# Depression Score Statistics:
# Mean: 1.69
# Std: 2.52
# Q1 (25th percentile): 0.00
# Q3 (75th percentile): 2.00
# IQR: 2.00
#
# Thresholds:
# Z-score method (2 SD above mean): 6.73
# IQR method (Q3 + 1.5*IQR): 5.00
#
# Depression Categories Distribution:
# depression_category
# low       0.458094
# medium    0.302952
# high      0.238954
# Name: proportion, dtype: float64
#
# Starting baseline data loading...
# Minimum required subjects per file: 8075
#
# Processing linked-external-data...
#   - led_l_seda_demo_c.csv: 8946 subjects (keeping)
#   - led_l_lodes.csv: 9604 subjects (keeping)
#   - led_l_denspop.csv: 9589 subjects (keeping)
#   - led_l_urbsat.csv: 9604 subjects (keeping)
#   - led_l_no2.csv: 9591 subjects (keeping)
#   - led_l_goodsam.csv: 9626 subjects (keeping)
#   - led_l_vpd.csv: 9599 subjects (keeping)
#   - led_l_medmj.csv: 9626 subjects (keeping)
#   - led_l_roadprox.csv: 9589 subjects (keeping)
#   - led_l_seda_pool_c.csv: 8946 subjects (keeping)
#   - led_l_densalc.csv: 9362 subjects (keeping)
#   - led_l_seda_read_c.csv: 8946 subjects (keeping)
#   - led_l_relciv.csv: 9604 subjects (keeping)
#   - led_l_censusret.csv: 9604 subjects (keeping)
#   - led_l_seda_demo_s.csv: 8977 subjects (keeping)
#   - led_l_seda_demo_d.csv: 8624 subjects (keeping)
#   - led_l_ejscreen.csv: 9604 subjects (keeping)
#   - led_l_seda_read_d.csv: 8624 subjects (keeping)
#   - led_l_noise.csv: 9604 subjects (keeping)
#   - led_l_places.csv: 9602 subjects (keeping)
#   - led_l_adi.csv: 9588 subjects (keeping)
#   - led_l_prenatal.csv: 7655 subjects (skipping - too few subjects)
#   - led_l_seda_pool_s.csv: 8977 subjects (keeping)
#   - led_l_seda_pool_d.csv: 8624 subjects (keeping)
#   - led_l_rxopioid.csv: 9604 subjects (keeping)
#   - led_l_elevation.csv: 7774 subjects (skipping - too few subjects)
#   - led_l_admin.csv: 9524 subjects (keeping)
#   - led_l_expint.csv: 8724 subjects (keeping)
#   - led_l_oz.csv: 4343 subjects (skipping - too few subjects)
#   - led_l_parks.csv: 9603 subjects (keeping)
#   - led_l_coi.csv: 9202 subjects (keeping)
#   - led_l_seda_math_z.csv: 8946 subjects (keeping)
#   - led_l_seda_math_m.csv: 8859 subjects (keeping)
#   - led_l_ice.csv: 9603 subjects (keeping)
#   - led_l_crime.csv: 9589 subjects (keeping)
#   - led_l_socmob.csv: 9205 subjects (keeping)
#   - led_l_densbld.csv: 9589 subjects (keeping)
#   - led_l_urban.csv: 9564 subjects (keeping)
#   - led_l_rxmonit.csv: 9626 subjects (keeping)
#   - led_l_biasrace.csv: 10091 subjects (keeping)
#   - led_l_densveh.csv: 9491 subjects (keeping)
#   - led_l_pm25.csv: 9591 subjects (keeping)
#   - led_l_temp.csv: 9599 subjects (keeping)
#   - led_l_seda_math_c.csv: 8946 subjects (keeping)
#   - led_l_socsrv.csv: 9604 subjects (keeping)
#   - led_l_traffic.csv: 9589 subjects (keeping)
#   - led_l_o3.csv: 9591 subjects (keeping)
#   - led_l_nbhsoc.csv: 9604 subjects (keeping)
#   - led_l_aca.csv: 9626 subjects (keeping)
#   - led_l_rxnalox.csv: 9626 subjects (keeping)
#   - led_l_seda_math_d.csv: 8624 subjects (keeping)
#   - led_l_mhsvi.csv: 9604 subjects (keeping)
#   - led_l_particulat.csv: 9604 subjects (keeping)
#   - led_l_biasgender.csv: 10091 subjects (keeping)
#   - led_l_lawsmj.csv: 10093 subjects (keeping)
#   - led_l_entropy.csv: 8724 subjects (keeping)
#   - led_l_leadrisk.csv: 9588 subjects (keeping)
#   - led_l_svi.csv: 9604 subjects (keeping)
#   - led_l_walk.csv: 9589 subjects (keeping)
#   - led_l_artsports.csv: 9604 subjects (keeping)
#   - led_l_polnalox.csv: 9626 subjects (keeping)
#   - led_l_biasimm.csv: 10091 subjects (keeping)
#   - led_l_dissim.csv: 8724 subjects (keeping)
#   - led_l_rentmort.csv: 9603 subjects (keeping)
#   - led_l_gi.csv: 9579 subjects (keeping)
#   - led_l_nlcd.csv: 9603 subjects (keeping)
#   - led_l_seda_demo_m.csv: 8859 subjects (keeping)
#   - led_l_seda_read_z.csv: 8946 subjects (keeping)
#   - led_l_seda_read_m.csv: 8859 subjects (keeping)
#   - led_l_seda_pool_m.csv: 8859 subjects (keeping)
#   - led_l_seda_pool_z.csv: 8946 subjects (keeping)
# Merging 68 files from linked-external-data...
# Completed linked-external-data merge. Shape: (10094, 2831)
#
# Processing gender-identity-sexual-health...
#   - gish_p_gi.csv: 10094 subjects (keeping)
#   - gish_y_sex.csv: 10083 subjects (keeping)
#   - gish_p_sex.csv: 10092 subjects (keeping)
#   - gish_y_gi.csv: 10087 subjects (keeping)
# Merging 4 files from gender-identity-sexual-health...
# Completed gender-identity-sexual-health merge. Shape: (10094, 127)
#
# Processing neurocognition...
#   - nc_y_flkr.csv: 0 subjects (skipping - too few subjects)
#   - nc_y_bird.csv: 0 subjects (skipping - too few subjects)
#   - nc_y_sit.csv: 0 subjects (skipping - too few subjects)
#   - nc_y_ddis.csv: 0 subjects (skipping - too few subjects)
#   - nc_y_svs.csv: 10084 subjects (keeping)
#   - nc_y_ehis.csv: 10094 subjects (keeping)
#   - nc_y_est.csv: 0 subjects (skipping - too few subjects)
#   - nc_y_adm.csv: 6337 subjects (skipping - too few subjects)
#   - nc_y_lmt.csv: 9792 subjects (keeping)
#   - nc_y_wisc.csv: 9942 subjects (keeping)
#   - nc_y_smarte.csv: 0 subjects (skipping - too few subjects)
#   - nc_y_gdt.csv: 0 subjects (skipping - too few subjects)
#   - nc_y_ravlt.csv: 9980 subjects (keeping)
#   - nc_p_bdef.csv: 0 subjects (skipping - too few subjects)
#   - nc_y_cct.csv: 10082 subjects (keeping)
#   - nc_y_nihtb.csv: 9981 subjects (keeping)
# Merging 7 files from neurocognition...
# Completed neurocognition merge. Shape: (10094, 254)
#
# Processing novel-technologies...
#   - nt_p_stq.csv: 10089 subjects (keeping)
#   - nt_y_ears_vibr_qtn_plt.csv: 0 subjects (skipping - too few subjects)
#   - nt_p_psq.csv: 0 subjects (skipping - too few subjects)
#   - nt_y_st.csv: 10094 subjects (keeping)
#   - nt_y_fitb_qtn_plt.csv: 131 subjects (skipping - too few subjects)
#   - nt_y_ears_qtn.csv: 0 subjects (skipping - too few subjects)
#   - nt_p_fitb_qtn.csv: 0 subjects (skipping - too few subjects)
#   - nt_p_ears_qtn_plt.csv: 0 subjects (skipping - too few subjects)
#   - nt_y_ears.csv: 0 subjects (skipping - too few subjects)
#   - nt_p_fitb_qtn_plt.csv: 131 subjects (skipping - too few subjects)
#   - nt_y_fitb_act_w.csv: 850 subjects (skipping - too few subjects)
#   - nt_y_vibr_plt.csv: 0 subjects (skipping - too few subjects)
#   - nt_y_fitb_slp_w.csv: 707 subjects (skipping - too few subjects)
#   - nt_y_fitb_qtn.csv: 0 subjects (skipping - too few subjects)
#   - nt_p_ears_qtn.csv: 0 subjects (skipping - too few subjects)
#   - nt_y_ears_plt.csv: 0 subjects (skipping - too few subjects)
#   - nt_y_fitb_slp_d.csv: 1251 subjects (skipping - too few subjects)
#   - nt_y_fitb_act_d.csv: 2545 subjects (skipping - too few subjects)
# Merging 2 files from novel-technologies...
# Completed novel-technologies merge. Shape: (10094, 223)
#
# Processing abcd-general...
#   - abcd_p_demo.csv: 10094 subjects (keeping)
#   - abcd_y_lt.csv: 10094 subjects (keeping)
#   - abcd_y_lf.csv: 7145 subjects (skipping - too few subjects)
#   - abcd_p_ocp.csv: 0 subjects (skipping - too few subjects)
#   - abcd_p_screen.csv: 0 subjects (skipping - too few subjects)
# Merging 2 files from abcd-general...
# Completed abcd-general merge. Shape: (10094, 285)
#
# Processing substance-use...
#   - su_y_uri_tox.csv: 0 subjects (skipping - too few subjects)
#   - su_p_plus.csv: 3409 subjects (skipping - too few subjects)
#   - su_y_hair_tox.csv: 10081 subjects (keeping)
#   - su_y_peertoler.csv: 0 subjects (skipping - too few subjects)
#   - su_y_can_cws.csv: 0 subjects (skipping - too few subjects)
#   - su_p_crpf.csv: 10092 subjects (keeping)
#   - su_y_ends_exp.csv: 0 subjects (skipping - too few subjects)
#   - su_y_alc_hss.csv: 10094 subjects (keeping)
#   - su_y_can_motiv.csv: 0 subjects (skipping - too few subjects)
#   - su_p_dse.csv: 0 subjects (skipping - too few subjects)
#   - su_y_can_mapi.csv: 2 subjects (skipping - too few subjects)
#   - su_y_alc_tox.csv: 10093 subjects (keeping)
#   - su_y_dapi.csv: 1 subjects (skipping - too few subjects)
#   - su_y_sui.csv: 10094 subjects (keeping)
#   - su_y_ends_motiv.csv: 0 subjects (skipping - too few subjects)
#   - su_y_vap_motiv.csv: 0 subjects (skipping - too few subjects)
#   - su_y_nic_dep.csv: 0 subjects (skipping - too few subjects)
#   - su_y_nic_tox.csv: 0 subjects (skipping - too few subjects)
#   - su_y_nic_motiv.csv: 0 subjects (skipping - too few subjects)
#   - su_y_ends_reas.csv: 0 subjects (skipping - too few subjects)
#   - su_y_ksads_sud.csv: 0 subjects (skipping - too few subjects)
#   - su_y_alc_eff.csv: 45 subjects (skipping - too few subjects)
#   - su_y_sal_tox.csv: 10094 subjects (keeping)
#   - su_y_plus.csv: 10088 subjects (keeping)
#   - su_y_nic_exp.csv: 0 subjects (skipping - too few subjects)
#   - su_y_tlfb.csv: 49 subjects (skipping - too few subjects)
#   - su_y_vap_exp.csv: 0 subjects (skipping - too few subjects)
#   - su_y_crpf.csv: 0 subjects (skipping - too few subjects)
#   - su_y_can_eff.csv: 45 subjects (skipping - too few subjects)
#   - su_y_sibuse.csv: 0 subjects (skipping - too few subjects)
#   - su_y_can_exp.csv: 0 subjects (skipping - too few subjects)
#   - su_y_peerdevia.csv: 9903 subjects (keeping)
#   - su_y_alc_rapi.csv: 0 subjects (skipping - too few subjects)
#   - su_p_ksads_sud.csv: 9897 subjects (keeping)
#   - su_y_path_intuse.csv: 9853 subjects (keeping)
#   - su_y_nic_eff.csv: 45 subjects (skipping - too few subjects)
#   - su_y_alc_exp.csv: 0 subjects (skipping - too few subjects)
#   - su_y_mypi.csv: 0 subjects (skipping - too few subjects)
#   - su_y_alc_motiv.csv: 0 subjects (skipping - too few subjects)
#   - su_y_percharm.csv: 0 subjects (skipping - too few subjects)
#   - su_p_pr.csv: 10092 subjects (keeping)
# Merging 11 files from substance-use...
# Completed substance-use merge. Shape: (10094, 1853)
#
# Processing mental-health...
#   - mh_y_cbb.csv: 0 subjects (skipping - too few subjects)
#   - mh_y_le.csv: 10094 subjects (keeping)
#   - mh_p_ksads_ss.csv: 9998 subjects (keeping)
#   - mh_t_bpm.csv: 10094 subjects (keeping)
#   - mh_p_ksads_sep.csv: 9895 subjects (keeping)
#   - mh_y_ksads_cd.csv: 0 subjects (skipping - too few subjects)
#   - mh_p_ksads_gad.csv: 9896 subjects (keeping)
#   - mh_p_ksads_ocd.csv: 9811 subjects (keeping)
#   - mh_p_ksads_hi.csv: 9895 subjects (keeping)
#   - mh_y_bisbas.csv: 10094 subjects (keeping)
#   - mh_y_ksads_bg.csv: 10092 subjects (keeping)
#   - mh_p_ksads_odd.csv: 9810 subjects (keeping)
#   - mh_p_ksads_ptsd.csv: 9832 subjects (keeping)
#   - Skipping mh_p_cbcl.csv (CBCL data excluded)
#   - mh_p_eatq.csv: 0 subjects (skipping - too few subjects)
#   - mh_p_ksads_phb.csv: 9811 subjects (keeping)
#   - mh_y_ksads_ed.csv: 0 subjects (skipping - too few subjects)
#   - mh_y_ksads_si.csv: 9969 subjects (keeping)
#   - mh_p_pss.csv: 0 subjects (skipping - too few subjects)
#   - mh_p_ksads_asd.csv: 9810 subjects (keeping)
#   - mh_y_ksads_gad.csv: 9969 subjects (keeping)
#   - mh_p_ksads_psy.csv: 9895 subjects (keeping)
#   - mh_y_7up.csv: 9039 subjects (keeping)
#   - mh_p_abcl.csv: 0 subjects (skipping - too few subjects)
#   - mh_p_ksads_bg.csv: 10092 subjects (keeping)
#   - mh_p_ksads_bp.csv: 9895 subjects (keeping)
#   - mh_y_pps.csv: 10094 subjects (keeping)
#   - mh_p_ksads_ago.csv: 4230 subjects (skipping - too few subjects)
#   - mh_p_ksads_dmdd.csv: 373 subjects (skipping - too few subjects)
#   - mh_y_peq.csv: 0 subjects (skipping - too few subjects)
#   - mh_p_ksads_sad.csv: 9896 subjects (keeping)
#   - mh_y_ksads_bip.csv: 9969 subjects (keeping)
#   - mh_y_ksads_dmdd.csv: 119 subjects (skipping - too few subjects)
#   - mh_p_ders.csv: 0 subjects (skipping - too few subjects)
#   - mh_p_ksads_slp.csv: 9895 subjects (keeping)
#   - mh_p_ksads_cd.csv: 9895 subjects (keeping)
#   - mh_p_ssrs.csv: 4076 subjects (skipping - too few subjects)
#   - mh_y_ksads_dep.csv: 9969 subjects (keeping)
#   - mh_y_ksads_ss.csv: 10051 subjects (keeping)
#   - mh_y_erq.csv: 0 subjects (skipping - too few subjects)
#   - mh_p_asr.csv: 10094 subjects (keeping)
#   - mh_p_fhx.csv: 10094 subjects (keeping)
#   - mh_y_upps.csv: 10094 subjects (keeping)
#   - mh_y_bpm.csv: 0 subjects (skipping - too few subjects)
#   - mh_y_ksads_sad.csv: 9969 subjects (keeping)
#   - mh_y_ksads_slp.csv: 9969 subjects (keeping)
#   - mh_p_ksads_dep.csv: 9895 subjects (keeping)
#   - mh_p_ksads_adhd.csv: 9801 subjects (keeping)
#   - mh_p_gbi.csv: 10094 subjects (keeping)
#   - mh_y_or.csv: 10079 subjects (keeping)
#   - mh_p_le.csv: 10094 subjects (keeping)
#   - mh_p_ksads_pd.csv: 9810 subjects (keeping)
#   - mh_y_poa.csv: 0 subjects (skipping - too few subjects)
#   - mh_p_ksads_si.csv: 9895 subjects (keeping)
#   - mh_p_ksads_ed.csv: 9896 subjects (keeping)
# Merging 39 files from mental-health...
# Completed mental-health merge. Shape: (10094, 8211)
#
# Processing culture-environment...
#   - ce_y_meim.csv: 0 subjects (skipping - too few subjects)
#   - ce_y_pbp.csv: 0 subjects (skipping - too few subjects)
#   - ce_y_wps.csv: 0 subjects (skipping - too few subjects)
#   - ce_y_mnbs.csv: 0 subjects (skipping - too few subjects)
#   - ce_p_pm.csv: 0 subjects (skipping - too few subjects)
#   - ce_p_comc.csv: 0 subjects (skipping - too few subjects)
#   - ce_p_macv.csv: 10094 subjects (keeping)
#   - ce_y_pet.csv: 0 subjects (skipping - too few subjects)
#   - ce_y_via.csv: 0 subjects (skipping - too few subjects)
#   - ce_p_via.csv: 10094 subjects (keeping)
#   - ce_y_srpf.csv: 10094 subjects (keeping)
#   - ce_y_rpi.csv: 0 subjects (skipping - too few subjects)
#   - ce_y_macv.csv: 0 subjects (skipping - too few subjects)
#   - ce_y_sag.csv: 0 subjects (skipping - too few subjects)
#   - ce_p_psb.csv: 10094 subjects (keeping)
#   - ce_p_sag.csv: 0 subjects (skipping - too few subjects)
#   - ce_p_meim.csv: 10093 subjects (keeping)
#   - ce_y_psb.csv: 10094 subjects (keeping)
#   - ce_y_acc.csv: 10083 subjects (keeping)
#   - ce_y_fes.csv: 10094 subjects (keeping)
#   - ce_p_nsc.csv: 10094 subjects (keeping)
#   - ce_p_acc.csv: 10092 subjects (keeping)
#   - ce_y_pm.csv: 10094 subjects (keeping)
#   - ce_y_crpbi.csv: 10094 subjects (keeping)
#   - ce_y_nsc.csv: 10079 subjects (keeping)
#   - ce_p_fes.csv: 10094 subjects (keeping)
#   - ce_y_dm.csv: 25 subjects (skipping - too few subjects)
#   - ce_y_pnh.csv: 0 subjects (skipping - too few subjects)
# Merging 14 files from culture-environment...
# Completed culture-environment merge. Shape: (10094, 326)
#
# Processing physical-health...
#   - ph_p_bfq.csv: 0 subjects (skipping - too few subjects)
#   - ph_p_sds.csv: 10094 subjects (keeping)
#   - ph_y_yrb.csv: 10075 subjects (keeping)
#   - ph_y_anthro.csv: 10093 subjects (keeping)
#   - ph_p_otbi.csv: 10094 subjects (keeping)
#   - ph_p_dhx.csv: 10094 subjects (keeping)
#   - ph_p_saiq.csv: 10092 subjects (keeping)
#   - ph_y_bp.csv: 0 subjects (skipping - too few subjects)
#   - ph_p_pds.csv: 10094 subjects (keeping)
#   - ph_y_bkfs.csv: 0 subjects (skipping - too few subjects)
#   - ph_y_bld.csv: 0 subjects (skipping - too few subjects)
#   - ph_y_pq.csv: 0 subjects (skipping - too few subjects)
#   - ph_y_mctq.csv: 0 subjects (skipping - too few subjects)
#   - ph_p_ipaq.csv: 0 subjects (skipping - too few subjects)
#   - ph_y_pds.csv: 10094 subjects (keeping)
#   - ph_y_covid.csv: 0 subjects (skipping - too few subjects)
#   - ph_p_teeth.csv: 4754 subjects (skipping - too few subjects)
#   - ph_p_meds.csv: 10088 subjects (keeping)
#   - ph_y_saiq.csv: 0 subjects (skipping - too few subjects)
#   - ph_p_mhx.csv: 10094 subjects (keeping)
#   - ph_y_resp.csv: 0 subjects (skipping - too few subjects)
#   - ph_p_bkfs.csv: 0 subjects (skipping - too few subjects)
#   - ph_y_sal_horm.csv: 10092 subjects (keeping)
#   - ph_p_covid.csv: 0 subjects (skipping - too few subjects)
#   - ph_p_cna.csv: 9295 subjects (keeping)
# Merging 12 files from physical-health...
# Completed physical-health merge. Shape: (10094, 2173)
#
# Merging all subdirectories...
# Merging subdirectory 2 of 9...
# Current shape: (10094, 2957)
# Merging subdirectory 3 of 9...
# Current shape: (10094, 3210)
# Merging subdirectory 4 of 9...
# Current shape: (10094, 3432)
# Merging subdirectory 5 of 9...
# Current shape: (10094, 3716)
# Merging subdirectory 6 of 9...
# Current shape: (10094, 5568)
# Merging subdirectory 7 of 9...
# Current shape: (10094, 13778)
# Merging subdirectory 8 of 9...
# Current shape: (10094, 14103)
# Merging subdirectory 9 of 9...
# Current shape: (10094, 16275)
#
# Final baseline dataset shape: (10094, 16275)
#
# Starting preprocessing pipeline...
# Starting data preprocessing pipeline...
#
# Handling missing values...
#
# Handling special values...
# Found 5 instances of 999 in reshist_addr1_LODES_totjobn_linked-external-data_led_l_lodes
# Found 1 instances of 555 in reshist_addr1_LODES_jobwn_linked-external-data_led_l_lodes
# Found 2 instances of 777 in reshist_addr1_LODES_jobwn_linked-external-data_led_l_lodes
# Found 1 instances of 999 in reshist_addr1_LODES_jobwn_linked-external-data_led_l_lodes
# Found 3 instances of 555 in reshist_addr1_LODES_jobbn_linked-external-data_led_l_lodes
# Found 1 instances of 777 in reshist_addr1_LODES_joban_linked-external-data_led_l_lodes
# Found 1 instances of 555 in reshist_addr1_LODES_jobnhn_linked-external-data_led_l_lodes
# Found 6 instances of 777 in reshist_addr1_LODES_jobnhn_linked-external-data_led_l_lodes
# Found 1 instances of 999 in reshist_addr1_LODES_jobnhn_linked-external-data_led_l_lodes
# Found 4 instances of 555 in reshist_addr1_LODES_jobhn_linked-external-data_led_l_lodes
# Found 2 instances of 555 in reshist_addr2_LODES_jobbn_linked-external-data_led_l_lodes
# Found 2 instances of 555 in reshist_addr1_adi_rent_linked-external-data_led_l_adi
# Found 2 instances of 777 in reshist_addr1_adi_rent_linked-external-data_led_l_adi
# Found 13 instances of 999 in reshist_addr1_adi_rent_linked-external-data_led_l_adi
# Found 3 instances of 777 in reshist_addr1_adi_mortg_linked-external-data_led_l_adi
# Found 4 instances of 999 in reshist_addr1_adi_mortg_linked-external-data_led_l_adi
# Found 1 instances of 999 in reshist_addr2_adi_rent_linked-external-data_led_l_adi
# Found 1 instances of 999 in reshist_addr3_adi_mortg_linked-external-data_led_l_adi
# Found 1 instances of 555 in reshist_addr1_nanda_parks_cty_linked-external-data_led_l_parks
# Found 1 instances of 555 in reshist_addr1_drugtot_linked-external-data_led_l_crime
# Found 1 instances of 555 in reshist_addr1_drgposs_linked-external-data_led_l_crime
# Found 1 instances of 555 in reshist_addr2_drugtot_linked-external-data_led_l_crime
# Found 8 instances of 555 in reshist_addr1_opat_kfrpp_n_linked-external-data_led_l_socmob
# Found 2 instances of 777 in reshist_addr1_opat_kfrpp_n_linked-external-data_led_l_socmob
# Found 1 instances of 999 in reshist_addr1_opat_kfrpp_n_linked-external-data_led_l_socmob
# Found 2 instances of 555 in reshist_addr2_opat_kfrpp_n_linked-external-data_led_l_socmob
# Found 10 instances of 777 in reshist_addr1_oz_medrent_linked-external-data_led_l_rentmort
# Found 6 instances of 999 in reshist_addr1_oz_medrent_linked-external-data_led_l_rentmort
# Found 1 instances of 999 in reshist_addr2_oz_medrent_linked-external-data_led_l_rentmort
# Found 2 instances of 777 in demo_gender_id_v2_gender-identity-sexual-health_gish_p_gi
# Found 3 instances of 999 in demo_gender_id_v2_gender-identity-sexual-health_gish_p_gi
# Found 3 instances of 999 in demo_adopt_agex_v2_bl_dk_abcd-general_abcd_p_demo
# Found 2 instances of 777 in demo_gender_id_v2_abcd-general_abcd_p_demo
# Found 3 instances of 999 in demo_gender_id_v2_abcd-general_abcd_p_demo
# Found 38 instances of 777 in demo_ethn_v2_abcd-general_abcd_p_demo
# Found 78 instances of 999 in demo_ethn_v2_abcd-general_abcd_p_demo
# Found 8 instances of 777 in demo_ethn2_v2_abcd-general_abcd_p_demo
# Found 28 instances of 999 in demo_ethn2_v2_abcd-general_abcd_p_demo
# Found 5 instances of 777 in demo_origin_v2_abcd-general_abcd_p_demo
# Found 6 instances of 999 in demo_origin_v2_abcd-general_abcd_p_demo
# Found 14 instances of 999 in demo_years_us_v2_dk_abcd-general_abcd_p_demo
# Found 111 instances of 777 in demo_relig_v2_abcd-general_abcd_p_demo
# Found 296 instances of 999 in demo_relig_v2_abcd-general_abcd_p_demo
# Found 39 instances of 777 in demo_prnt_age_v2_bl_refuse_abcd-general_abcd_p_demo
# Found 26 instances of 999 in demo_prnt_age_v2_bl_refuse_abcd-general_abcd_p_demo
# Found 3 instances of 777 in demo_prnt_gender_id_v2_abcd-general_abcd_p_demo
# Found 1 instances of 999 in demo_prnt_gender_id_v2_abcd-general_abcd_p_demo
# Found 30 instances of 999 in naas_id_abcd-general_abcd_p_demo
# Found 47 instances of 999 in naas_mom_id_abcd-general_abcd_p_demo
# Found 92 instances of 999 in naas_id_dad_abcd-general_abcd_p_demo
# Found 78 instances of 999 in naas_birthplace_abcd-general_abcd_p_demo
# Found 70 instances of 999 in naas_raised_abcd-general_abcd_p_demo
# Found 66 instances of 999 in naas_comm_contact_abcd-general_abcd_p_demo
# Found 36 instances of 999 in naas_pride_abcd-general_abcd_p_demo
# Found 19 instances of 999 in naas_self_rating_abcd-general_abcd_p_demo
# Found 13 instances of 999 in naas_traditions_abcd-general_abcd_p_demo
# Found 16 instances of 777 in demo_prnt_ethn_v2_abcd-general_abcd_p_demo
# Found 37 instances of 999 in demo_prnt_ethn_v2_abcd-general_abcd_p_demo
# Found 8 instances of 999 in demo_prnt_ethn2_v2_abcd-general_abcd_p_demo
# Found 3 instances of 999 in demo_prnt_origin_v2_abcd-general_abcd_p_demo
# Found 1 instances of 777 in demo_biofather_v2_abcd-general_abcd_p_demo
# Found 33 instances of 999 in demo_biofather_v2_abcd-general_abcd_p_demo
# Found 15 instances of 999 in demo_biomother_v2_abcd-general_abcd_p_demo
# Found 31 instances of 999 in demo_matgrandm_v2_abcd-general_abcd_p_demo
# Found 43 instances of 999 in demo_matgrandf_v2_abcd-general_abcd_p_demo
# Found 4 instances of 777 in demo_patgrandm_v2_abcd-general_abcd_p_demo
# Found 78 instances of 999 in demo_patgrandm_v2_abcd-general_abcd_p_demo
# Found 4 instances of 777 in demo_patgrandf_v2_abcd-general_abcd_p_demo
# Found 99 instances of 999 in demo_patgrandf_v2_abcd-general_abcd_p_demo
# Found 95 instances of 999 in demo_prnt_years_us_v2_dk_abcd-general_abcd_p_demo
# Found 55 instances of 777 in demo_prnt_marital_v2_abcd-general_abcd_p_demo
# Found 11 instances of 777 in demo_prnt_ed_v2_abcd-general_abcd_p_demo
# Found 32 instances of 777 in demo_prnt_empl_v2_abcd-general_abcd_p_demo
# Found 481 instances of 777 in demo_prnt_income_v2_abcd-general_abcd_p_demo
# Found 377 instances of 999 in demo_prnt_income_v2_abcd-general_abcd_p_demo
# Found 85 instances of 777 in demo_prnt_prtnr_v2_abcd-general_abcd_p_demo
# Found 10 instances of 777 in demo_prnt_prtnr_bio_abcd-general_abcd_p_demo
# Found 1 instances of 999 in demo_prnt_prtnr_bio_abcd-general_abcd_p_demo
# Found 9 instances of 777 in demo_prtnr_ed_v2_abcd-general_abcd_p_demo
# Found 47 instances of 999 in demo_prtnr_ed_v2_abcd-general_abcd_p_demo
# Found 53 instances of 777 in demo_prtnr_empl_v2_abcd-general_abcd_p_demo
# Found 21 instances of 999 in demo_prtnr_empl_v2_abcd-general_abcd_p_demo
# Found 336 instances of 777 in demo_prtnr_income_v2_abcd-general_abcd_p_demo
# Found 398 instances of 999 in demo_prtnr_income_v2_abcd-general_abcd_p_demo
# Found 388 instances of 777 in demo_comb_income_v2_abcd-general_abcd_p_demo
# Found 375 instances of 999 in demo_comb_income_v2_abcd-general_abcd_p_demo
# Found 51 instances of 777 in demo_fam_exp1_v2_abcd-general_abcd_p_demo
# Found 29 instances of 777 in demo_fam_exp2_v2_abcd-general_abcd_p_demo
# Found 46 instances of 777 in demo_fam_exp3_v2_abcd-general_abcd_p_demo
# Found 21 instances of 777 in demo_fam_exp4_v2_abcd-general_abcd_p_demo
# Found 27 instances of 777 in demo_fam_exp5_v2_abcd-general_abcd_p_demo
# Found 27 instances of 777 in demo_fam_exp6_v2_abcd-general_abcd_p_demo
# Found 35 instances of 777 in demo_fam_exp7_v2_abcd-general_abcd_p_demo
# Found 117 instances of 777 in demo_roster_v2_refuse_abcd-general_abcd_p_demo
# Found 62 instances of 999 in demo_roster_v2_refuse_abcd-general_abcd_p_demo
# Found 55 instances of 777 in demo_child_time_v2_abcd-general_abcd_p_demo
# Found 11 instances of 777 in demo_child_time2_v2_dk_abcd-general_abcd_p_demo
# Found 47 instances of 999 in demo_child_time2_v2_dk_abcd-general_abcd_p_demo
# Found 102 instances of 777 in demo_yrs_1_abcd-general_abcd_p_demo
# Found 84 instances of 999 in demo_yrs_1_abcd-general_abcd_p_demo
# Found 85 instances of 777 in demo_yrs_2_abcd-general_abcd_p_demo
# Found 238 instances of 999 in demo_yrs_2_abcd-general_abcd_p_demo
# Found 412 instances of 999 in demo_yrs_2a_2_abcd-general_abcd_p_demo
# Found 648 instances of 999 in demo_yrs_2b_2_abcd-general_abcd_p_demo
# Found 3 instances of 777 in demo_prnt_gender_id_v2_l_abcd-general_abcd_p_demo
# Found 1 instances of 999 in demo_prnt_gender_id_v2_l_abcd-general_abcd_p_demo
# Found 1 instances of 777 in demo_prtnr_empl_v2_l_abcd-general_abcd_p_demo
# Found 1 instances of 777 in demo_prtnr_indust_refuse_l_abcd-general_abcd_p_demo
# Found 2 instances of 999 in demo_prtnr_income_v2_l_abcd-general_abcd_p_demo
# Found 1 instances of 777 in demo_yrs_1_l_abcd-general_abcd_p_demo
# Found 1 instances of 777 in demo_yrs_2_l_abcd-general_abcd_p_demo
# Found 1 instances of 555 in rel_family_id_abcd-general_abcd_y_lt
# Found 1 instances of 777 in rel_family_id_abcd-general_abcd_y_lt
# Found 1 instances of 999 in rel_family_id_abcd-general_abcd_y_lt
# Found 557 instances of 999 in su_risk_p_9_substance-use_su_p_crpf
# Found 1 instances of 777 in isip_1_substance-use_su_y_sui
# Found 1 instances of 777 in su_isip_1_calc_substance-use_su_y_sui
# Found 1 instances of 999 in tlfb_cig_lt_dk_substance-use_su_y_sui
# Found 1 instances of 999 in tlfb_ecig_lt_dk_substance-use_su_y_sui
# Found 8 instances of 999 in tlfb_ecig_lt_size_substance-use_su_y_sui
# Found 1 instances of 999 in tlfb_cigar_lt_dk_substance-use_su_y_sui
# Found 1 instances of 999 in tlfb_chew_lt_dk_substance-use_su_y_sui
# Found 2 instances of 999 in tlfb_lt_nicotine_dk_substance-use_su_y_sui
# Found 3 instances of 999 in tlfb_mj_lt_dk_substance-use_su_y_sui
# Found 1 instances of 999 in tlfb_hall_lt_dk_substance-use_su_y_sui
# Found 2 instances of 999 in tlfb_cough_lt_dk_substance-use_su_y_sui
# Found 1 instances of 999 in tlfb_chew_max_dk_substance-use_su_y_sui
# Found 3 instances of 999 in tlfb_cigar_max_dk_substance-use_su_y_sui
# Found 1 instances of 999 in tlfb_nicotine_max_dk_substance-use_su_y_sui
# Found 2 instances of 999 in tlfb_mj_max_dk_substance-use_su_y_sui
# Found 1 instances of 999 in tlfb_bsalts_max_dk_substance-use_su_y_sui
# Found 1 instances of 999 in tlfb_tranq_max_dk_substance-use_su_y_sui
# Found 1 instances of 999 in tlfb_vicodin_max_dk_substance-use_su_y_sui
# Found 2 instances of 999 in tlfb_cough_max_dk_substance-use_su_y_sui
# Found 1 instances of 999 in tlfb_other_max_dk_substance-use_su_y_sui
# Found 1 instances of 999 in tlfb_6mo_1_ecig_dk_substance-use_su_y_sui
# Found 2 instances of 999 in tlfb_6mo_2_ecig_dk_substance-use_su_y_sui
# Found 1 instances of 999 in tlfb_6mo_4_mj_dk_substance-use_su_y_sui
# Found 9998 instances of 555 in ksads_12_928_p_mental-health_mh_p_ksads_ss
# Found 9998 instances of 555 in ksads_12_927_p_mental-health_mh_p_ksads_ss
# Found 9998 instances of 555 in ksads_12_925_p_mental-health_mh_p_ksads_ss
# Found 9998 instances of 555 in ksads_12_926_p_mental-health_mh_p_ksads_ss
# Found 9998 instances of 555 in ksads_12_53_p_mental-health_mh_p_ksads_ss
# Found 9998 instances of 555 in ksads_12_52_p_mental-health_mh_p_ksads_ss
# Found 9998 instances of 555 in ksads_12_56_p_mental-health_mh_p_ksads_ss
# Found 9998 instances of 555 in ksads_12_57_p_mental-health_mh_p_ksads_ss
# Found 9998 instances of 555 in ksads_12_60_p_mental-health_mh_p_ksads_ss
# Found 9998 instances of 555 in ksads_12_54_p_mental-health_mh_p_ksads_ss
# Found 9998 instances of 555 in ksads_12_55_p_mental-health_mh_p_ksads_ss
# Found 9998 instances of 555 in ksads_12_61_p_mental-health_mh_p_ksads_ss
# Found 9998 instances of 555 in ksads_12_64_p_mental-health_mh_p_ksads_ss
# Found 9998 instances of 555 in ksads_12_65_p_mental-health_mh_p_ksads_ss
# Found 9998 instances of 555 in ksads_12_62_p_mental-health_mh_p_ksads_ss
# Found 9998 instances of 555 in ksads_12_63_p_mental-health_mh_p_ksads_ss
# Found 9998 instances of 555 in ksads_12_58_p_mental-health_mh_p_ksads_ss
# Found 9998 instances of 555 in ksads_12_59_p_mental-health_mh_p_ksads_ss
# Found 9998 instances of 555 in ksads_17_905_p_mental-health_mh_p_ksads_ss
# Found 9998 instances of 555 in ksads_17_904_p_mental-health_mh_p_ksads_ss
# Found 9998 instances of 555 in ksads_17_110_p_mental-health_mh_p_ksads_ss
# Found 9998 instances of 555 in ksads_17_111_p_mental-health_mh_p_ksads_ss
# Found 9998 instances of 555 in ksads_17_109_p_mental-health_mh_p_ksads_ss
# Found 9998 instances of 555 in ksads_17_108_p_mental-health_mh_p_ksads_ss
# Found 9998 instances of 555 in ksads_25_916_p_mental-health_mh_p_ksads_ss
# Found 9998 instances of 555 in ksads_25_915_p_mental-health_mh_p_ksads_ss
# Found 9998 instances of 555 in ksads_25_866_p_mental-health_mh_p_ksads_ss
# Found 9998 instances of 555 in ksads_25_865_p_mental-health_mh_p_ksads_ss
# Found 9998 instances of 555 in ksads_25_314_p_mental-health_mh_p_ksads_ss
# Found 9998 instances of 555 in ksads_25_315_p_mental-health_mh_p_ksads_ss
# Found 9998 instances of 555 in ksads_25_316_p_mental-health_mh_p_ksads_ss
# Found 9998 instances of 555 in ksads_25_317_p_mental-health_mh_p_ksads_ss
# Found 9998 instances of 555 in ksads_25_32_p_mental-health_mh_p_ksads_ss
# Found 9998 instances of 555 in ksads_25_33_p_mental-health_mh_p_ksads_ss
# Found 9998 instances of 555 in ksads_25_318_p_mental-health_mh_p_ksads_ss
# Found 9998 instances of 555 in ksads_25_319_p_mental-health_mh_p_ksads_ss
# Found 3 instances of 777 in kbi_p_c_det_susp_mental-health_mh_p_ksads_bg
# Found 28 instances of 999 in kbi_p_c_age_services_bl_dk_mental-health_mh_p_ksads_bg
# Found 3 instances of 999 in kbi_p_c_mental_health_dk_mental-health_mh_p_ksads_bg
# Found 10051 instances of 555 in ksads_4_16_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_4_17_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_4_18_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_4_19_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_5_20_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_5_21_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_6_22_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_6_23_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_7_24_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_7_25_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_7_26_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_7_27_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_25_32_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_9_34_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_9_35_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_9_36_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_9_37_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_9_38_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_9_39_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_9_40_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_9_41_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_9_42_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_9_43_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_11_48_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_11_49_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_11_50_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_12_52_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_12_53_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_12_54_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_12_55_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_12_56_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_12_57_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_12_58_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_12_59_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_12_60_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_12_61_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_12_62_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_12_63_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_12_64_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_13_66_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_13_67_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_13_68_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_13_69_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_13_70_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_13_71_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_13_72_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_13_73_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_13_74_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_14_76_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_14_77_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_14_78_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_14_79_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_14_80_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_14_81_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_14_82_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_14_83_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_14_84_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_14_85_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_14_86_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_14_87_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_14_88_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_14_89_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_15_91_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_15_92_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_15_93_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_15_94_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_15_95_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_15_96_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_15_97_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_16_98_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_16_99_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_16_100_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_16_101_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_16_102_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_16_103_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_16_104_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_16_105_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_16_106_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_16_107_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_17_108_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_17_109_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_17_110_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_17_111_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_18_112_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_18_113_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_18_114_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_18_115_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_18_116_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_18_117_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_19_120_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_19_121_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_19_122_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_19_123_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_19_124_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_20_126_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_20_127_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_20_128_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_20_129_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_20_130_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_20_131_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_20_132_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_20_133_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_134_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_135_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_136_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_137_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_138_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_139_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_140_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_24_151_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_24_152_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_24_153_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_24_154_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_4_230_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_4_231_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_4_232_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_4_233_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_4_234_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_4_235_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_4_236_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_4_237_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_4_238_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_4_239_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_4_240_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_4_241_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_4_242_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_4_243_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_4_244_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_4_245_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_4_246_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_4_247_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_4_248_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_4_249_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_4_250_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_4_251_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_4_252_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_4_253_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_4_254_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_4_255_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_4_256_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_4_257_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_4_258_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_4_259_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_4_260_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_5_261_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_5_262_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_5_263_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_5_264_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_5_265_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_5_266_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_5_267_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_5_268_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_5_269_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_5_270_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_6_272_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_6_273_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_6_274_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_6_275_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_6_276_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_6_277_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_6_278_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_6_279_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_7_281_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_7_282_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_7_283_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_7_284_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_7_285_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_7_286_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_7_287_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_7_288_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_7_289_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_7_290_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_7_291_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_7_292_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_7_293_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_7_294_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_7_295_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_7_296_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_7_297_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_7_298_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_7_299_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_7_300_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_25_314_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_25_315_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_25_316_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_25_317_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_25_318_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_25_319_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_11_331_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_11_332_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_11_333_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_11_334_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_11_335_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_11_336_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_11_337_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_11_338_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_11_339_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_11_340_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_11_341_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_11_342_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_11_343_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_11_344_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_11_345_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_11_346_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_11_347_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_11_348_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_349_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_350_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_351_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_352_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_353_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_354_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_355_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_356_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_357_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_358_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_359_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_360_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_361_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_362_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_363_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_364_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_365_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_366_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_367_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_368_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_369_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_370_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_371_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_372_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_373_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_374_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_375_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_376_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_377_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_378_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_379_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_380_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_381_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_382_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_383_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_384_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_385_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_386_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_387_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_388_t_mental-health_mh_y_ksads_ss
# Found 10051 instances of 555 in ksads_21_389_t_mental-health_mh_y_ksads_ss
# ...
# Log transforming sai_p_activities___11_physical-health_ph_p_saiq (skewness: 5.64)
# Log transforming sai_p_activities___12_physical-health_ph_p_saiq (skewness: 16.21)
# Log transforming sai_p_activities___13_physical-health_ph_p_saiq (skewness: 4.66)
# Log transforming sai_p_activities___14_physical-health_ph_p_saiq (skewness: 2.98)
# Log transforming sai_p_activities___16_physical-health_ph_p_saiq (skewness: 14.25)
# Log transforming sai_p_activities___18_physical-health_ph_p_saiq (skewness: 3.46)
# Log transforming sai_p_activities___19_physical-health_ph_p_saiq (skewness: 3.30)
# Log transforming sai_p_activities___20_physical-health_ph_p_saiq (skewness: 5.54)
# Log transforming sai_p_activities___21_physical-health_ph_p_saiq (skewness: 5.83)
# Log transforming sai_p_activities___22_physical-health_ph_p_saiq (skewness: 6.71)
# Log transforming sai_p_activities___24_physical-health_ph_p_saiq (skewness: 1.44)
# Log transforming sai_p_activities___25_physical-health_ph_p_saiq (skewness: 2.46)
# Log transforming sai_p_activities___26_physical-health_ph_p_saiq (skewness: 2.84)
# Log transforming sai_p_activities___27_physical-health_ph_p_saiq (skewness: 2.37)
# Log transforming sai_p_activities___28_physical-health_ph_p_saiq (skewness: 3.35)
# Log transforming sai_p_activities___29_physical-health_ph_p_saiq (skewness: 2.74)
# Log transforming sai_p_lmusic_physical-health_ph_p_saiq (skewness: -1.84)
# Log transforming sai_p_read_physical-health_ph_p_saiq (skewness: -1.12)
# Log transforming sai_ss_dance_nyr_p_physical-health_ph_p_saiq (skewness: 2.75)
# Log transforming sai_ss_dance_nmonth_p_physical-health_ph_p_saiq (skewness: 1.57)
# Log transforming sai_ss_dance_perwk_p_physical-health_ph_p_saiq (skewness: 3.50)
# Log transforming sai_ss_dance_tspent_p_physical-health_ph_p_saiq (skewness: 1.48)
# Log transforming sai_ss_base_nyr_p_physical-health_ph_p_saiq (skewness: 2.08)
# Log transforming sai_ss_base_nmonth_p_physical-health_ph_p_saiq (skewness: 2.05)
# Log transforming sai_ss_base_perwk_p_physical-health_ph_p_saiq (skewness: 1.64)
# Log transforming sai_ss_base_tspent_p_physical-health_ph_p_saiq (skewness: 1.19)
# Log transforming sai_ss_basket_nyr_p_physical-health_ph_p_saiq (skewness: 2.42)
# Log transforming sai_ss_basket_nmonth_p_physical-health_ph_p_saiq (skewness: 2.36)
# Log transforming sai_ss_basket_perwk_p_physical-health_ph_p_saiq (skewness: 2.10)
# Log transforming sai_ss_basket_tspent_p_physical-health_ph_p_saiq (skewness: 1.30)
# Log transforming sai_ss_climb_nyr_p_physical-health_ph_p_saiq (skewness: 9.79)
# Log transforming sai_ss_climb_nmonth_p_physical-health_ph_p_saiq (skewness: 8.63)
# Log transforming sai_ss_climb_perwk_p_physical-health_ph_p_saiq (skewness: 10.36)
# Log transforming sai_ss_climb_tspent_p_physical-health_ph_p_saiq (skewness: 6.77)
# Log transforming sai_ss_fhock_nyr_p_physical-health_ph_p_saiq (skewness: 22.33)
# Log transforming sai_ss_fhock_nmonth_p_physical-health_ph_p_saiq (skewness: 19.12)
# Log transforming sai_ss_fhock_perwk_p_physical-health_ph_p_saiq (skewness: 22.64)
# Log transforming sai_ss_fhock_tspent_p_physical-health_ph_p_saiq (skewness: 13.74)
# Log transforming sai_ss_fball_nyr_p_physical-health_ph_p_saiq (skewness: 4.31)
# Log transforming sai_ss_fball_nmonth_p_physical-health_ph_p_saiq (skewness: 4.00)
# Log transforming sai_ss_fball_perwk_p_physical-health_ph_p_saiq (skewness: 3.46)
# Log transforming sai_ss_fball_tspent_p_physical-health_ph_p_saiq (skewness: 2.81)
# Log transforming sai_ss_gym_nyr_p_physical-health_ph_p_saiq (skewness: 2.98)
# Log transforming sai_ss_gym_nmonth_p_physical-health_ph_p_saiq (skewness: 1.87)
# Log transforming sai_ss_gym_perwk_p_physical-health_ph_p_saiq (skewness: 3.35)
# Log transforming sai_ss_gym_tspent_p_physical-health_ph_p_saiq (skewness: 1.74)
# Log transforming sai_ss_ihock_nyr_p_physical-health_ph_p_saiq (skewness: 8.25)
# Log transforming sai_ss_ihock_nmonth_p_physical-health_ph_p_saiq (skewness: 7.72)
# Log transforming sai_ss_ihock_perwk_p_physical-health_ph_p_saiq (skewness: 7.45)
# Log transforming sai_ss_ihock_tspent_p_physical-health_ph_p_saiq (skewness: 6.35)
# Log transforming sai_ss_polo_nyr_p_physical-health_ph_p_saiq (skewness: 8.92)
# Log transforming sai_ss_polo_nmonth_p_physical-health_ph_p_saiq (skewness: 7.28)
# Log transforming sai_ss_polo_perwk_p_physical-health_ph_p_saiq (skewness: 10.84)
# Log transforming sai_ss_polo_tspent_p_physical-health_ph_p_saiq (skewness: 6.14)
# Log transforming sai_ss_iskate_nyr_p_physical-health_ph_p_saiq (skewness: 6.21)
# Log transforming sai_ss_iskate_nmonth_p_physical-health_ph_p_saiq (skewness: 6.00)
# Log transforming sai_ss_iskate_perwk_p_physical-health_ph_p_saiq (skewness: 9.67)
# Log transforming sai_ss_iskate_tspent_p_physical-health_ph_p_saiq (skewness: 4.62)
# Log transforming sai_ss_m_arts_nyr_p_physical-health_ph_p_saiq (skewness: 3.40)
# Log transforming sai_ss_m_arts_nmonth_p_physical-health_ph_p_saiq (skewness: 2.21)
# Log transforming sai_ss_m_arts_perwk_p_physical-health_ph_p_saiq (skewness: 3.05)
# Log transforming sai_ss_m_arts_tspent_p_physical-health_ph_p_saiq (skewness: 1.94)
# Log transforming sai_ss_lax_nyr_p_physical-health_ph_p_saiq (skewness: 9.04)
# Log transforming sai_ss_lax_nmonth_p_physical-health_ph_p_saiq (skewness: 8.33)
# Log transforming sai_ss_lax_perwk_p_physical-health_ph_p_saiq (skewness: 6.97)
# Log transforming sai_ss_lax_tspent_p_physical-health_ph_p_saiq (skewness: 5.96)
# Log transforming sai_ss_rugby_nyr_p_physical-health_ph_p_saiq (skewness: 26.88)
# Log transforming sai_ss_rugby_nmonth_p_physical-health_ph_p_saiq (skewness: 25.67)
# Log transforming sai_ss_rugby_perwk_p_physical-health_ph_p_saiq (skewness: 22.95)
# Log transforming sai_ss_rugby_tspent_p_physical-health_ph_p_saiq (skewness: 18.20)
# Log transforming sai_ss_skate_nyr_p_physical-health_ph_p_saiq (skewness: 7.80)
# Log transforming sai_ss_skate_nmonth_p_physical-health_ph_p_saiq (skewness: 7.08)
# Log transforming sai_ss_skate_perwk_p_physical-health_ph_p_saiq (skewness: 7.67)
# Log transforming sai_ss_skate_tspent_p_physical-health_ph_p_saiq (skewness: 6.94)
# Log transforming sai_ss_sboard_nyr_p_physical-health_ph_p_saiq (skewness: 3.95)
# Log transforming sai_ss_sboard_nmonth_p_physical-health_ph_p_saiq (skewness: 3.72)
# Log transforming sai_ss_sboard_perwk_p_physical-health_ph_p_saiq (skewness: 5.87)
# Log transforming sai_ss_sboard_tspent_p_physical-health_ph_p_saiq (skewness: 3.21)
# Log transforming sai_ss_soc_nyr_p_physical-health_ph_p_saiq (skewness: 1.36)
# Log transforming sai_ss_soc_nmonth_p_physical-health_ph_p_saiq (skewness: 1.48)
# Log transforming sai_ss_soc_perwk_p_physical-health_ph_p_saiq (skewness: 1.15)
# Log transforming sai_ss_surf_nyr_p_physical-health_ph_p_saiq (skewness: 23.85)
# Log transforming sai_ss_surf_nmonth_p_physical-health_ph_p_saiq (skewness: 29.94)
# Log transforming sai_ss_surf_perwk_p_physical-health_ph_p_saiq (skewness: 26.68)
# Log transforming sai_ss_surf_tspent_p_physical-health_ph_p_saiq (skewness: 18.79)
# Log transforming sai_ss_wpolo_nyr_p_physical-health_ph_p_saiq (skewness: 1.91)
# Log transforming sai_ss_wpolo_nmonth_p_physical-health_ph_p_saiq (skewness: 1.89)
# Log transforming sai_ss_wpolo_perwk_p_physical-health_ph_p_saiq (skewness: 2.17)
# Log transforming sai_ss_wpolo_tspent_p_physical-health_ph_p_saiq (skewness: 1.38)
# Log transforming sai_ss_tennis_nyr_p_physical-health_ph_p_saiq (skewness: 5.56)
# Log transforming sai_ss_tennis_nmonth_p_physical-health_ph_p_saiq (skewness: 5.65)
# Log transforming sai_ss_tennis_perwk_p_physical-health_ph_p_saiq (skewness: 7.48)
# Log transforming sai_ss_tennis_tspent_p_physical-health_ph_p_saiq (skewness: 3.98)
# Log transforming sai_ss_run_nyr_p_physical-health_ph_p_saiq (skewness: 5.60)
# Log transforming sai_ss_run_nmonth_p_physical-health_ph_p_saiq (skewness: 5.36)
# Log transforming sai_ss_run_perwk_p_physical-health_ph_p_saiq (skewness: 5.55)
# Log transforming sai_ss_run_tspent_p_physical-health_ph_p_saiq (skewness: 3.93)
# Log transforming sai_ss_mma_nyr_p_physical-health_ph_p_saiq (skewness: 9.22)
# Log transforming sai_ss_mma_nmonth_p_physical-health_ph_p_saiq (skewness: 8.02)
# Log transforming sai_ss_mma_perwk_p_physical-health_ph_p_saiq (skewness: 7.51)
# Log transforming sai_ss_mma_tspent_p_physical-health_ph_p_saiq (skewness: 6.30)
# Log transforming sai_ss_vball_nyr_p_physical-health_ph_p_saiq (skewness: 9.11)
# Log transforming sai_ss_vball_nmonth_p_physical-health_ph_p_saiq (skewness: 8.74)
# Log transforming sai_ss_vball_perwk_p_physical-health_ph_p_saiq (skewness: 10.32)
# Log transforming sai_ss_vball_tspent_p_physical-health_ph_p_saiq (skewness: 6.36)
# Log transforming sai_ss_yoga_nyr_p_physical-health_ph_p_saiq (skewness: 12.75)
# Log transforming sai_ss_yoga_nmonth_p_physical-health_ph_p_saiq (skewness: 10.00)
# Log transforming sai_ss_yoga_perwk_p_physical-health_ph_p_saiq (skewness: 16.23)
# Log transforming sai_ss_yoga_tspent_p_physical-health_ph_p_saiq (skewness: 7.94)
# Log transforming sai_ss_music_nyr_p_physical-health_ph_p_saiq (skewness: 1.91)
# Log transforming sai_ss_music_perwk_p_physical-health_ph_p_saiq (skewness: 2.27)
# Log transforming sai_ss_music_tspent_p_physical-health_ph_p_saiq (skewness: 1.06)
# Log transforming sai_ss_art_nyr_p_physical-health_ph_p_saiq (skewness: 2.70)
# Log transforming sai_ss_art_nmonth_p_physical-health_ph_p_saiq (skewness: 2.11)
# Log transforming sai_ss_art_perwk_p_physical-health_ph_p_saiq (skewness: 3.20)
# Log transforming sai_ss_art_tspent_p_physical-health_ph_p_saiq (skewness: 2.27)
# Log transforming sai_ss_drama_nyr_p_physical-health_ph_p_saiq (skewness: 4.72)
# Log transforming sai_ss_drama_nmonth_p_physical-health_ph_p_saiq (skewness: 3.97)
# Log transforming sai_ss_drama_perwk_p_physical-health_ph_p_saiq (skewness: 4.82)
# Log transforming sai_ss_drama_tspent_p_physical-health_ph_p_saiq (skewness: 3.14)
# Log transforming sai_ss_crafts_nyr_p_physical-health_ph_p_saiq (skewness: 4.79)
# Log transforming sai_ss_crafts_nmonth_p_physical-health_ph_p_saiq (skewness: 3.93)
# Log transforming sai_ss_crafts_perwk_p_physical-health_ph_p_saiq (skewness: 5.35)
# Log transforming sai_ss_crafts_tspent_p_physical-health_ph_p_saiq (skewness: 3.94)
# Log transforming sai_ss_chess_nyr_p_physical-health_ph_p_saiq (skewness: 4.35)
# Log transforming sai_ss_chess_nmonth_p_physical-health_ph_p_saiq (skewness: 3.53)
# Log transforming sai_ss_chess_perwk_p_physical-health_ph_p_saiq (skewness: 5.98)
# Log transforming sai_ss_chess_tspent_p_physical-health_ph_p_saiq (skewness: 3.02)
# Log transforming sai_ss_collect_nyr_p_physical-health_ph_p_saiq (skewness: 5.29)
# Log transforming sai_ss_collect_nmonth_p_physical-health_ph_p_saiq (skewness: 4.33)
# Log transforming sai_ss_collect_perwk_p_physical-health_ph_p_saiq (skewness: 5.46)
# Log transforming sai_ss_collect_tspent_p_physical-health_ph_p_saiq (skewness: 6.40)
# Log transforming sai_ss_lmusic_hours_p_physical-health_ph_p_saiq (skewness: 7.72)
# Log transforming sai_ss_read_hours_p_physical-health_ph_p_saiq (skewness: 10.80)
# Log transforming pds_2_p_physical-health_ph_p_pds (skewness: 1.29)
# Log transforming pds_3_p_physical-health_ph_p_pds (skewness: 1.43)
# Log transforming caff_24_physical-health_ph_p_meds (skewness: 1.67)
# Log transforming rx_med_select_language___1_physical-health_ph_p_meds (skewness: 4.68)
# Log transforming medhx_1a_physical-health_ph_p_mhx (skewness: 2.27)
# Log transforming medhx_1b_physical-health_ph_p_mhx (skewness: 4.03)
# Log transforming medhx_4a_physical-health_ph_p_mhx (skewness: 6.37)
# Log transforming medhx_5a_physical-health_ph_p_mhx (skewness: 3.90)
# Log transforming medhx_8a_physical-health_ph_p_mhx (skewness: 5.41)
# Log transforming medhx_9a_physical-health_ph_p_mhx (skewness: 4.57)
# Log transforming medhx_11_physical-health_ph_p_mhx (skewness: -5.53)
# Log transforming medhx_12_physical-health_ph_p_mhx (skewness: -5.83)
# Log transforming medhx_ss_4b_p_physical-health_ph_p_mhx (skewness: 3.22)
# Log transforming medhx_ss_6a_times_p_physical-health_ph_p_mhx (skewness: 6.61)
# Log transforming medhx_ss_6b_times_p_physical-health_ph_p_mhx (skewness: 6.92)
# Log transforming medhx_ss_6c_times_p_physical-health_ph_p_mhx (skewness: 19.91)
# Log transforming medhx_ss_6d_times_p_physical-health_ph_p_mhx (skewness: 3.32)
# Log transforming medhx_ss_6e_times_p_physical-health_ph_p_mhx (skewness: 23.84)
# Log transforming medhx_ss_6f_times_p_physical-health_ph_p_mhx (skewness: 13.64)
# Log transforming medhx_ss_6g_times_p_physical-health_ph_p_mhx (skewness: 13.86)
# Log transforming medhx_ss_6h_times_p_physical-health_ph_p_mhx (skewness: 5.30)
# Log transforming medhx_ss_6i_times_p_physical-health_ph_p_mhx (skewness: 4.02)
# Log transforming medhx_ss_6j_times_p_physical-health_ph_p_mhx (skewness: 10.84)
# Log transforming medhx_ss_6k_times_p_physical-health_ph_p_mhx (skewness: 26.54)
# Log transforming medhx_ss_6l_times_p_physical-health_ph_p_mhx (skewness: 11.49)
# Log transforming medhx_ss_6m_times_p_physical-health_ph_p_mhx (skewness: 6.11)
# Log transforming medhx_ss_6n_times_p_physical-health_ph_p_mhx (skewness: 9.06)
# Log transforming medhx_ss_6o_times_p_physical-health_ph_p_mhx (skewness: 39.27)
# Log transforming medhx_ss_6p_times_p_physical-health_ph_p_mhx (skewness: 33.94)
# Log transforming medhx_ss_6q_times_p_physical-health_ph_p_mhx (skewness: 14.25)
# Log transforming medhx_ss_9b_p_physical-health_ph_p_mhx (skewness: 3.87)
# Log transforming medhx_ss_6t_times_p_physical-health_ph_p_mhx (skewness: 37.20)
# Log transforming hormone_sal_caff_y_physical-health_ph_y_sal_horm (skewness: 3.59)
# Log transforming hormone_sal_active_physical-health_ph_y_sal_horm (skewness: 2.45)
# Log transforming hormon_sal_notes_y___1_physical-health_ph_y_sal_horm (skewness: -2.00)
# Log transforming hormon_sal_notes_y___2_physical-health_ph_y_sal_horm (skewness: 9.51)
# Log transforming hormon_sal_notes_y___3_physical-health_ph_y_sal_horm (skewness: 6.00)
# Log transforming hormon_sal_notes_y___4_physical-health_ph_y_sal_horm (skewness: 3.96)
# Log transforming hormon_sal_notes_y___5_physical-health_ph_y_sal_horm (skewness: 3.74)
# Log transforming hormon_sal_notes_y___6_physical-health_ph_y_sal_horm (skewness: 3.87)
# Log transforming hormone_scr_dhea_mean_physical-health_ph_y_sal_horm (skewness: 2.23)
# Log transforming hormone_scr_dhea_rep1_ll_physical-health_ph_y_sal_horm (skewness: 10.10)
# Log transforming hormone_scr_dhea_rep1_qns_physical-health_ph_y_sal_horm (skewness: 15.59)
# Log transforming hormone_scr_dhea_rep1_nd_physical-health_ph_y_sal_horm (skewness: 10.96)
# Log transforming hormone_scr_dhea_rep2_physical-health_ph_y_sal_horm (skewness: 2.19)
# Log transforming hormone_scr_dhea_rep2_ll_physical-health_ph_y_sal_horm (skewness: 9.42)
# Log transforming hormone_scr_dhea_rep2_qns_physical-health_ph_y_sal_horm (skewness: 12.96)
# Log transforming hormone_scr_dhea_rep2_nd_physical-health_ph_y_sal_horm (skewness: 9.60)
# Log transforming hormone_scr_ert_mean_physical-health_ph_y_sal_horm (skewness: 4.75)
# Log transforming hormone_scr_ert_rep1_physical-health_ph_y_sal_horm (skewness: 4.91)
# Log transforming hormone_scr_ert_rep1_qns_physical-health_ph_y_sal_horm (skewness: 28.95)
# Log transforming hormone_scr_ert_rep1_nd_physical-health_ph_y_sal_horm (skewness: 71.02)
# Log transforming hormone_scr_ert_rep2_physical-health_ph_y_sal_horm (skewness: 4.52)
# Log transforming hormone_scr_ert_rep2_ll_physical-health_ph_y_sal_horm (skewness: 50.20)
# Log transforming hormone_scr_ert_rep2_qns_physical-health_ph_y_sal_horm (skewness: 24.30)
# Log transforming hormone_scr_ert_rep2_nd_physical-health_ph_y_sal_horm (skewness: 44.90)
#
# Removing correlated features...
# Removed 2375 highly correlated variables
#
# Scaling depression score...
#
# Depression score statistics after scaling:
# count    1.009400e+04
# mean    -1.337459e-17
# std      1.000050e+00
# min     -6.705033e-01
# 25%     -6.705033e-01
# 50%     -2.737823e-01
# 75%      1.229387e-01
# max      7.660638e+00
# Name: depression_score, dtype: float64
#
# Final preprocessed dataset:
# Shape: (10094, 2359)
#
# Final preprocessed dataset:
# Shape: (10094, 2359)
#
# Feature types:
# float64    2301
# int64        57
# object        1
# Name: count, dtype: int64
#
# Preprocessed data saved to: ../data/processed/preprocessed_data.csv
#
# Done!
